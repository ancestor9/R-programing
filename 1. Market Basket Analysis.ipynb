# %% [markdown]
# ## **[Market Basket Analysis](https://www.youtube.com/watch?v=yzDGvZEtYdQ&list=PLPv2Jc-avQHAJx1X0pcicuVI2x2nCkzhz&index=23)**
#
# ### **[Obtain transactional data](https://www.kaggle.com/datasets/virtualschool/market-basket-analysis?resource=download)**

# %%
import pandas as pd
df = pd.read_csv('/content/Market Basket Analysis.csv')
df
# Out:
#         BillNo                             Itemname  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365                  WHITE METAL LANTERN         6
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...                                  ...       ...
# 522056  581587          PACK OF 20 SPACEBOY NAPKINS        12
# 522057  581587          CHILDREN'S APRON DOLLY GIRL         6
# 522058  581587         CHILDRENS CUTLERY DOLLY GIRL         4
# 522059  581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 522060  581587         BAKING SET 9 PIECE RETROSPOT         3
#
#                    Date  Price  CustomerID         Country
# 0        12/1/2010 8:26   2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26   3.39     17850.0  United Kingdom
# ...

# %%
df[df['BillNo'] == 536365]
# Out:
#    BillNo                             Itemname  Quantity            Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  12/1/2010 8:26
# 1  536365                  WHITE METAL LANTERN         6  12/1/2010 8:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  12/1/2010 8:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  12/1/2010 8:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  12/1/2010 8:26
# 5  536365         SET 7 BABUSHKA NESTING BOXES         2  12/1/2010 8:26
# 6  536365    GLASS STAR FROSTED T-LIGHT HOLDER         6  12/1/2010 8:26
#
#    Price  CustomerID         Country
# 0   2.55     17850.0  United Kingdom
# 1   3.39     17850.0  United Kingdom
# 2   2.75     17850.0  United Kingdom
# 3   3.39     17850.0  United Kingdom
# 4   3.39     17850.0  United Kingdom
# 5   7.65     17850.0  United Kingdom
# 6   4.25     17850.0  United Kingdom

# %%
df['Itemname'].value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER     2269
# JUMBO BAG RED RETROSPOT                2087
# REGENCY CAKESTAND 3 TIER               1930
# PARTY BUNTING                          1677
# LUNCH BAG RED RETROSPOT                1570
#                                        ...
# found box                                 1
# HAYNES CAMPER SHOULDER BAG                1
# for online retail orders                  1
# add stock to allocate online orders       1
# PAPER CRAFT  LITTLE BIRDIE                1
# Name: Itemname, Length: 4175, dtype: int64

# %%
df[df['Itemname'] == 'WHITE HANGING HEART T-LIGHT HOLDER']
# Out:
#         BillNo                            Itemname  Quantity             Date  \
# 0       536365  WHITE HANGING HEART T-LIGHT HOLDER         6   12/1/2010 8:26
# 49      536373  WHITE HANGING HEART T-LIGHT HOLDER         6   12/1/2010 9:02
# 66      536375  WHITE HANGING HEART T-LIGHT HOLDER         6   12/1/2010 9:32
# 218     536390  WHITE HANGING HEART T-LIGHT HOLDER        64  12/1/2010 10:19
# 253     536394  WHITE HANGING HEART T-LIGHT HOLDER        32  12/1/2010 10:39
# ...        ...                                 ...       ...              ...
# 517568  581246  WHITE HANGING HEART T-LIGHT HOLDER         1  12/8/2011 10:59
# 517603  581253  WHITE HANGING HEART T-LIGHT HOLDER         2  12/8/2011 11:15
# 518119  581356  WHITE HANGING HEART T-LIGHT HOLDER         6  12/8/2011 12:28
# 520157  581452  WHITE HANGING HEART T-LIGHT HOLDER        32  12/8/2011 18:03
# 520376  581472  WHITE HANGING HEART T-LIGHT HOLDER         6  12/8/2011 19:55
#
# ...

# %%
White = df[df['Itemname'] == 'WHITE HANGING HEART T-LIGHT HOLDER']
White['BillNo'].nunique()
# Out:
# 2202

# %%
# prompt: White DataFrame 사용: BillNo가 중복된 행을 나타내라

White[White.duplicated('BillNo')]
# Out:
#         BillNo                            Itemname  Quantity  \
# 7515    537051  WHITE HANGING HEART T-LIGHT HOLDER         2
# 7575    537054  WHITE HANGING HEART T-LIGHT HOLDER         1
# 17230   537769  WHITE HANGING HEART T-LIGHT HOLDER         2
# 25033   538379  WHITE HANGING HEART T-LIGHT HOLDER         2
# 33143   539317  WHITE HANGING HEART T-LIGHT HOLDER         3
# ...        ...                                 ...       ...
# 468203  577742  WHITE HANGING HEART T-LIGHT HOLDER         1
# 475278  578255  WHITE HANGING HEART T-LIGHT HOLDER         1
# 481029  578688  WHITE HANGING HEART T-LIGHT HOLDER         1
# 491633  579458  WHITE HANGING HEART T-LIGHT HOLDER         1
# 506324  580635  WHITE HANGING HEART T-LIGHT HOLDER         3
#
#                     Date  Price  CustomerID         Country
# 7515     12/5/2010 11:12   2.95     15708.0  United Kingdom
# 7575     12/5/2010 11:40   2.95     16931.0  United Kingdom
# ...

# %%
White[White['BillNo'] ==  537051]
# Out:
#       BillNo                            Itemname  Quantity             Date  \
# 7511  537051  WHITE HANGING HEART T-LIGHT HOLDER         3  12/5/2010 11:12
# 7515  537051  WHITE HANGING HEART T-LIGHT HOLDER         2  12/5/2010 11:12
#
#       Price  CustomerID         Country
# 7511   2.95     15708.0  United Kingdom
# 7515   2.95     15708.0  United Kingdom

# %%
df[df['BillNo'] ==  537051]
# Out:
#       BillNo                            Itemname  Quantity             Date  \
# 7502  537051        COFFEE MUG CAT + BIRD DESIGN         6  12/5/2010 11:12
# 7503  537051      COFFEE MUG BLUE PAISLEY DESIGN         6  12/5/2010 11:12
# 7504  537051        COFFEE MUG DOG + BALL DESIGN         6  12/5/2010 11:12
# 7505  537051             BLACK HEART CARD HOLDER         1  12/5/2010 11:12
# 7506  537051       CARDHOLDER HOLLY WREATH METAL         1  12/5/2010 11:12
# 7507  537051                FORKED CACTUS CANDLE         6  12/5/2010 11:12
# 7508  537051    RED HANGING HEART T-LIGHT HOLDER         3  12/5/2010 11:12
# 7509  537051     SET 12 RETRO WHITE CHALK STICKS         1  12/5/2010 11:12
# 7510  537051                         WICKER STAR         2  12/5/2010 11:12
# 7511  537051  WHITE HANGING HEART T-LIGHT HOLDER         3  12/5/2010 11:12
# 7512  537051     CANDLEHOLDER PINK HANGING HEART         2  12/5/2010 11:12
# ...

# %%
df[df['BillNo'] ==  537051]['Itemname'].value_counts()
# Out:
# ALARM CLOCK BAKELIKE RED              3
# ALARM CLOCK BAKELIKE IVORY            3
# SET 12 RETRO WHITE CHALK STICKS       2
# ALARM CLOCK BAKELIKE GREEN            2
# ALARM CLOCK BAKELIKE ORANGE           2
# S/4 CACTI CANDLES                     2
# CACTI T-LIGHT CANDLES                 2
# WHITE HANGING HEART T-LIGHT HOLDER    2
# ALARM CLOCK BAKELIKE CHOCOLATE        2
# IVORY KITCHEN SCALES                  1
# METAL 4 HOOK HANGER FRENCH CHATEAU    1
# RED KITCHEN SCALES                    1
# SWEETHEART WIRE FRUIT BOWL            1
# CREAM SWEETHEART EGG HOLDER           1
# CREAM SWEETHEART LETTER RACK          1
# GOLD MUG BONE CHINA TREE OF LIFE      1
# WOOD 2 DRAWER CABINET WHITE FINISH    1
# COFFEE MUG PINK PAISLEY DESIGN        1
# SWEETHEART CAKESTAND 3 TIER           1
# COFFEE MUG CAT + BIRD DESIGN          1
# COFFEE MUG BLUE PAISLEY DESIGN        1
# HEART OF WICKER SMALL                 1
# HEART OF WICKER LARGE                 1
# ...
